# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as sk

# %%
names = ["carol", "albert", "ben "]   
print (" & ".join(sorted(names)))


#Lists
#Lists are enclosed in brackets
Name = ['vijay', 'denanath', 'chauhan']
Name.append ('Malum_Nahi')
Name


# Dictionary 
'''
Dictionaries are build using curly brackets
Note: Dictionaries are unordered but have key, value pairs and mutable
'''

person = {'name':'fred', 'age':37}
print(person['name'],person['age'])

population = {'Shanghai': 17.8, 'Istanbul': 13.3, 'Karachi':13.0, 'Mumbai':12.5}
list(population.keys())
list(population.values())
print(population)


# Complex and more useful example of dictionary
book_info = { 'title': 'Learning Python',
'pages': 342,
'pub_date': 'November 2016',
'chapters': 14,
}
print("The book is called %(title)s, and it was released on %(pub_date)s." 
      "It is %(pages)d pages long with %(chapters)d chapters." % book_info)

# %% [markdown]
# # SET
# A set is like a list but it can only hold unique values.
#
# pet1= set(['hello','world','friends','how'])
# pet2 = set(['how','are','you','friends','are'])
# pet2
#
# another important use of SET is that as it only hold unique values it can remove dups from a list
# numbers = [1,2,3,4,5,6,6,7,7]
# Sets support the in operator the same as lists do. You can add elements to sets using the add method, and remove elements using the pop method, similar to lists hence making it as MUTABLE OPTION. Remember set are unordered so while we pop a random observation wouild be deleted

# %%
# %matplotlib inline  # this code helps to produce the graphs inline/below to the code of the program
# Out:
# UsageError: unrecognized arguments: # this code helps to produce the graphs inline/below to the code of the program

# %%
pd.options.display.max_rows=12

# %%
compl= pd.read_excel("Maruti_Org_Data.xlsx")
compl.head(3)
# Out:
#   REGISTRATION_NUMBER TV_NTV_CATEGORY  VEH_MODEL OLD_CAR_BVEH_CODE  \
# 0           KL24N8556              TV       ALTO                 A
# 1           PB35Y3132              TV        CAR                 C
# 2          JK01AF1545              TV  NEW SWIFT                SM
#
#   NEW_CAR_MODEL  PURCHASE_BINARY  CLUSTER_ID  OLD_CAR_PURCHASE_YRS  \
# 0           NaN                0    14754855                  0.58
# 1     NEW SWIFT                1    13601946                  1.72
# 2       ALTO800                0    27641648                  0.59
#
#    OLD_CAR_PURCHASE_MNTH DEALER_ZONE  ... AUTOCARD_POINTS  \
# 0                      8          S3  ...             NaN
# 1                      6          N2  ...             NaN
# 2                      7          N2  ...             NaN
#
#    ACARD_PTS_PAID_LAST_YEAR  NO_OF_POLICIES  CLAIM_COUNT  CLAIM_AMT  \
# 0                       NaN             NaN          NaN        NaN
# ...

# %%
compl.head(5)  # here earlier Claim_Amt was appearing as NaN which means not a numbr hence no expression could be
#built on it 

compl.head(2).transpose()
# Out:
#                                           0                  1
# REGISTRATION_NUMBER               KL24N8556          PB35Y3132
# TV_NTV_CATEGORY                          TV                 TV
# VEH_MODEL                              ALTO                CAR
# OLD_CAR_BVEH_CODE                         A                  C
# NEW_CAR_MODEL                           NaN          NEW SWIFT
# PURCHASE_BINARY                           0                  1
# CLUSTER_ID                         14754855           13601946
# OLD_CAR_PURCHASE_YRS                   0.58               1.72
# OLD_CAR_PURCHASE_MNTH                     8                  6
# DEALER_ZONE                              S3                 N2
# DEALER_STATE                         KERALA             PUNJAB
# KMS_RUN                                 NaN                NaN
# SERVICES_COUNT                            1                  4
# INSU_CLAIM_COUNTS                       NaN                NaN
# ...

# %%
# FInding Total Null Values 
compl.CLAIM_AMT.isnull()
compl.CLAIM_AMT.isna().sum() # so total 47117 values are null 

#compl.shape  # total values are 49745
#47117/49745  # approx. 95% of the values are missing
# Out:
# 47117

# %%
# To select any specific column
compl[ 'NEW_CAR_MODEL']
# Out:
# 0                    NaN
# 1              NEW SWIFT
# 2                ALTO800
# 3        NEW SWIFT DZIRE
# 4                 ERTIGA
# 5                CELERIO
# 6            NEW WAGON-R
# 7                    NaN
# 8           NEW ALTO K10
# 9                    NaN
# 10               CELERIO
# 11               ALTO800
# 12               CELERIO
# 13               CELERIO
# 14             NEW SWIFT
# 15       NEW SWIFT DZIRE
# 16                   NaN
# 17               CELERIO
# 18               ALTO800
# 19             NEW SWIFT
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                ERTIGA
# 24                   NaN
# 25       NEW SWIFT DZIRE
# 26          NEW ALTO K10
# 27               CELERIO
# 28           NEW WAGON-R
# 29                  CIAZ
#               ...
# 49715    NEW SWIFT DZIRE
# 49716            CELERIO
# 49717                NaN
# 49718        NEW WAGON-R
# 49719        NEW WAGON-R
# 49720        NEW WAGON-R
# ...

# %%
compl[["NEW_CAR_MODEL", "PURCHASE_BINARY"]].head(5)   # pull data from 2 variables 
new = compl[["NEW_CAR_MODEL", "PURCHASE_BINARY"]]
new [0:4]
# Out:
#      NEW_CAR_MODEL  PURCHASE_BINARY
# 0              NaN                0
# 1        NEW SWIFT                1
# 2          ALTO800                0
# 3  NEW SWIFT DZIRE                0

# %%
compl[(compl['NEW_CAR_MODEL']=='NEW SWIFT DZIRE')
   & compl['PURCHASE_BINARY']==1]
# Out:
#       REGISTRATION_NUMBER TV_NTV_CATEGORY    VEH_MODEL OLD_CAR_BVEH_CODE  \
# 83             TN10XW2418              TV         ALTO                 A
# 196            TEMP974789              TV         EECO                 R
# 201            TEMP932765              TV          ZEN                 Y
# 236             TN84W5200              TV          ZEN                 Y
# 253              KL25J749              TV          ZEN                 Y
# 257            PB06AH4309              TV  NEW WAGON-R                 W
# ...                   ...             ...          ...               ...
# 49656         TEMPAB31362              TV    NEW SWIFT                SM
# 49658           DMYB33553              TV         ALTO                 A
# 49677          TEMPB22560              TV         RITZ                 D
# 49715         TEMP0B30036              TV  NEW WAGON-R                WM
# 49732           DMYB32250              TV      ALTO800                AN
# ...

# %%
# to know the names of the variables- Similar to names in R 
compl.columns
compl.columns.tolist()
# Out:
# ['REGISTRATION_NUMBER',
#  'TV_NTV_CATEGORY',
#  'VEH_MODEL',
#  'OLD_CAR_BVEH_CODE',
#  'NEW_CAR_MODEL',
#  'PURCHASE_BINARY',
#  'CLUSTER_ID',
#  'OLD_CAR_PURCHASE_YRS',
#  'OLD_CAR_PURCHASE_MNTH',
#  'DEALER_ZONE',
#  'DEALER_STATE',
#  'KMS_RUN',
#  'SERVICES_COUNT',
#  'INSU_CLAIM_COUNTS',
#  'INSU_CLAIM_TOT_VAL',
#  'PAID_SRV_COST',
#  'SERVICE_TYPE',
#  'PROJECTED_KM_CURR',
#  'OLD_CAR_KM_WHILE_BUYING',
#  'GENDER',
#  'RESI_CITY',
#  'RESI_STATE',
#  'OCCUPATION',
#  'TWO_YR_CUST',
#  'SERVICE_GAP_YRS',
#  'CUSTOMER_YRS',
#  'AGE',
#  'BIRTH_MONTH',
#  'VEH_COUNT',
#  'NO_OF_VEH',
#  'TOT_ACARD_PTS',
#  'CNT_EXCHANGE',
#  'LASTEST_BUY_GAP_YRS',
#  'AUTOCARD_POINTS',
#  'ACARD_PTS_PAID_LAST_YEAR',
#  'NO_OF_POLICIES',
#  'CLAIM_COUNT',
#  'CLAIM_AMT',
#  'TOT_TXNS_ALL_VEH',
#  'MAX_TRAN_YRS',
#  'NO_ALL_VEH',
#  'MONETARY_VALUE_ALL_VEH',
#  'NEW_CAR_BVEH_CODE']

# %%
compl.index  # row level information
# Out:
# RangeIndex(start=0, stop=49745, step=1)

# %%
compl.shape  # similar to dim to show total rows and columns
# Out:
# (49745, 43)

# %%
compl.iloc[:, 4:10] # how to use subset of data  fetching column 4 to 10th and all rows
# Out:
#          NEW_CAR_MODEL  PURCHASE_BINARY  CLUSTER_ID  OLD_CAR_PURCHASE_YRS  \
# 0                  NaN                0    14754855                  0.58
# 1            NEW SWIFT                1    13601946                  1.72
# 2              ALTO800                0    27641648                  0.59
# 3      NEW SWIFT DZIRE                0    27641651                  0.59
# 4               ERTIGA                0    27641656                  0.59
# 5              CELERIO                0    27641659                  0.60
# ...                ...              ...         ...                   ...
# 49739          ALTO800                1    35522057                  0.06
# 49740  NEW SWIFT DZIRE                1    35594288                  0.06
# 49741              NaN                1    35504861                  0.06
# 49742           ERTIGA                1    35518387                  0.05
# 49743             EECO                1    35519300                  0.05
# ...

# %%
# high level statistical information
compl.describe()
compl["SERVICES_COUNT"].describe()
compl['SERVICES_COUNT'].mean()
# Out:
# 2.7048166151126822

# %%
#if we need to find a specific condition, for example below we are finding from the new car model bvariable show all rows 
#items where the dealer state is PONDICHERRY
compl['NEW_CAR_MODEL'][compl['DEALER_STATE']=='PONDICHERRY']
# Out:
# 957          CELERIO
# 1004             NaN
# 1144             NaN
# 1207          ERTIGA
# 1292     NEW WAGON-R
# 1296             NaN
#             ...
# 49292            NaN
# 49391        ALTO800
# 49457            NaN
# 49527      NEW SWIFT
# 49550        ALTO800
# 49666    NEW WAGON-R
# Name: NEW_CAR_MODEL, Length: 266, dtype: object

# %% [markdown]
# #How to Treat Missing Numerical Values In Python with pandas

# %%
"""
We have one of the variable SERVICES_COUNT. this variable has few missing columsn, so as an easy fix we need to replace 
missing with 0. hence we use the below function from pandas . This is just an illustration and not a correct approach to fill
in missing values
"""
compl.SERVICES_COUNT.isna().sum()  # total 2222 are missing observations 
compl.fillna(0, inplace=True)
#compl["SERVICES_COUNT"].mean()

# %% [markdown]
# # Kaggle Machine Learning

# %%
Kaggle= pd.read_csv("Train.csv", low_memory=False)
# SOMETIME WE GET ERROR LOW_MEMORY = TRUE AND OUR DATA DOES NOT READ IN - COULD BE ANY DATA SOURCE THIS IS BECASE PANDAS 
#READS THE DATA TYPE FOR EACH VARIABLE ROW BY ROW AND IF THE SAME COLUMN HAS DIFFERENT DATA TYPES IT WILL CREATE AN ISSUE 
#HENCE WE SHOULD SPECIFY LOW_MEMORY= FALSE
Kaggle.describe().transpose()
# For this SalePrice is the outcome variable 
Kaggle.shape
# Out:
# (401125, 53)

# %% [markdown]
# PER KAGGLE FOR THIS COMPETITION THE SELECTION CRITERIA FOR THE TOP MODEL IS RMSLE (ROOT MEAN SQUARE LOG ERROR)
# THIS IS THE DIFFERENCE BETWEEN LOG OF OUR PREDICTED PRICE VS OUR ACTUAL PRICE AND THEN SQUARE IT AND THEN ADD
#
# *** BOld is done by __string__
#
# __In Most of the cases, for instance for price or sales generally we dont care much by we the target was missed by 10 dollars
# but more by what %__
# Hence we take the log of these numeric values

# %%
#The First step Here would be convert our continuous variable to a log which is sales
Kaggle.SalePrice = np.log(Kaggle.SalePrice)
Kaggle.SalePrice.head(4)
# Out:
# 0    11.097410
# 1    10.950807
# 2     9.210340
# 3    10.558414
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Initial Processing

# %%
# to download and install fastai need to follow
"""
https://github.com/fastai/fastai
it needs to be installed on anaconda prompt as an admin
"""
import fastai
from fastai.imports import * # this imports everything from fastai library 
from fastai.text import *
from pandas_summary import DataFrameSummary
from IPython.display import display

# %%
Kaggle.head(4)
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246  11.097410     999089     3157         121           3.0      2004
# 1  1139248  10.950807     117657       77         121           3.0      1996
# 2  1139249   9.210340     434808     7009         121           3.0      2001
# 3  1139251  10.558414    1026470      332         121           3.0      2001
#
#    MachineHoursCurrentMeter UsageBand         saledate  ...  \
# 0                      68.0       Low  11/16/2006 0:00  ...
# 1                    4640.0       Low   3/26/2004 0:00  ...
# 2                    2838.0      High   2/26/2004 0:00  ...
# 3                    3486.0      High   5/19/2011 0:00  ...
#
#   Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# 0                     NaN          NaN   NaN             NaN          NaN
# 1                     NaN          NaN   NaN             NaN          NaN
# ...

# %%
import sklearn as sk
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
# as random forest help in both classifcation and regression so RandomForestClassifier and RandomForestRegressor respectively 
#do these tasks 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
m = RandomForestRegressor(n_jobs=-1) # here usinf sklearn we are calling what do we want to do in our case as its 
#regression we are calling regressor

m.fit(Kaggle.drop('SalePrice', axis=1), Kaggle.SalePrice) 
#This code throws as error as there are categorical values in data

"""
Here in python, similar to R in the above statement we are fitting a model and we are asking for all variables to be 
included apart from the outcome variable which is SalePrice so we use .drop from pandas 
and then we are specifing which data set we need to use in our case it is: Kaggle.SalePrice

Note: If we do a shift tab after kaggle.drop Python shows and explain us this sklearn regression model using Random Forest
"""

#Once we run the above model fit statement, it throws an error and asks to converts categorical values into numeric values 
# model building
# Out:
# C:\Users\51613014\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-a2ec6b271a89> in <module>
#       8 #regression we are calling regressor
#       9
# ---> 10 m.fit(Kaggle.drop('SalePrice', axis=1), Kaggle.SalePrice)
#      11 #This code throws as error as there are categorical values in data
#      12
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
# ...

# %%
 from subprocess import check_output
Kaggle.saledate

# here we initially when had this variable loaded it was in python Series data type so with below code we are converting it 
#to date time formate 
Kaggle['saledate'] = pd.to_datetime(Kaggle['saledate'])

Kaggle.saledate.head(4)
# Out:
# 0   2006-11-16
# 1   2004-03-26
# 2   2004-02-26
# 3   2011-05-19
# Name: saledate, dtype: datetime64[ns]

# %% [markdown]
# from sklearn.ensemble import RandomForestClassifier
# rf = RandomForestClassifier()
# rf.fit(X_train, y_train)

# %%
def add_datepart(df, fldname, drop=True, time=False):
    "Helper function that adds columns relevant to a date."
    fld = df[fldname]
    fld_dtype = fld.dtype
    if isinstance(fld_dtype, pd.core.dtypes.dtypes.DatetimeTZDtype):
        fld_dtype = np.datetime64

    if not np.issubdtype(fld_dtype, np.datetime64):
        df[fldname] = fld = pd.to_datetime(fld, infer_datetime_format=True)
    targ_pre = re.sub('[Dd]ate$', '', fldname)
    attr = ['Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear',
            'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
    if time: attr = attr + ['Hour', 'Minute', 'Second']
    for n in attr: df[targ_pre + n] = getattr(fld.dt, n.lower())
    df[targ_pre + 'Elapsed'] = fld.astype(np.int64) // 10 ** 9
    if drop: df.drop(fldname, axis=1, inplace=True)

# %% [markdown]
# ## Random Forest

# %%
#??add_datepart 
# this is the function from Fast Ai to pull the informaton from dates - year,month, week, day of the month ,is month end,
#is month start etc.

# %%
fld= Kaggle.saledate
fld
fld.dt.year.head(3)
# from here we can read the dates from fld variable which needs to be followed with the name fld and then dt as pandas 
#reads the date variables in date format hence we need to mentioned dt before it
# Out:
# 0    2006
# 1    2004
# 2    2004
# Name: saledate, dtype: int64
